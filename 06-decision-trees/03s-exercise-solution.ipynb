# %% [markdown]
# ## Part 1: Decision Trees With Grid Search
#
# Look at the sklearn [DecisionTreeClassifier documentation](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html). For each hyperparameter:
#
# * Decide if it will impact the results or exclusively impact the computational speed.
#     * **Only the `ccp_alpha` value exclusively impacts computational speed.**
#     * However, some values don't always make sense...
#     * For example, you'll only want to use `class_weight` unless you have imbalanced classes in your dataset [(learn more here)](https://machinelearningmastery.com/cost-sensitive-decision-trees-for-imbalanced-classification/)
# * Pick at least 3 values for each hyperparameter that you'd like to include in your grid search.
#     * If there are fewer than 3 valid choices, include all valid choices.
#     * Carefully consider the choices, try to predict the impact of this hyperparameter on the outcome.
#     * Does this hyperparameter interact with others?
#
# See my choices of values below.
#
#
# **criterion** {“gini”, “entropy”}, default=”gini”
#
# > Typically you'll end up with similar results using either of these. Gini is a bit faster to compute than entropy. Gini is a measure of "purity" while entropy is a measure of information/randomness. With Gini we are saying we want to maximize each split for homogeniety, with entropy we are maximizing the amount of "information gained" by performing the split in terms of reducing the randomness in the node. [Read more](https://towardsdatascience.com/gini-index-vs-information-entropy-7a7e4fed3fcb)
#
# **splitter** {“best”, “random”}, default=”best”
#
# > Best is most commonly used, and what almost everyone means when they describe a decision tree (including the lesson that this homework is based on...). Random will select still look at evrey feature but randomly select one split point per feature, then choose the best feature. I don't suggest it TBH — if you want to do something like this use a random forest instead. Using random will potentially avoid overfitting, but it will likely also decrease performance overall.
#
# **max_depth** int, default=None
#
# > The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples. Shallow trees won't overfit as much, but at the risk of underfitting. Very shallow trees will only be allowed a few splits, whereas deeper trees will be allowed more. As the number of classess increases you may wish to increase the max_depth to allow your tree enough capacity to split out the classes. For example, if you have 10 classes, but a max depth of 3 (root->mid->leaf) then you'll have 4 leaf nodes, representing only 4 out of your possible 10 classes.
#
#
# **min_samples_split** int or float, default=2
#
# > The minimum number of samples required to split an internal node. Larger numbers here will smooth out the model by forcing your leaf nodes to represent a larger sub-sample of the data. This is especially true in regresssion trees, since you'll use the mean of that sub-sample as your prediction. However, as a consequence, with large numbers you might end up with "impure" leaf nodes that really ought to be split further.
#
#
# **min_weight_fraction_leaf** float, default=0.0
#
# > The minimum weighted fraction of the sum total of weights (of all the input samples) required to be at a leaf node. Samples have equal weight when sample_weight is not provided. This is similar to min_samples_split but more useful when you have imbalanced classes and are using class_weight.
#
#
# **max_features** int, float or {“auto”, “sqrt”, “log2”}, default=None
#
# > Artificially limit the number of features that can be considered at each split point. If you choose a value less than the number of features available that number of features will be randomly sampled per split. This is very common in random forests, and in a single decision tree it CAN have a regularizing effect but I don't generally recommend it.  This will also speed up the computational time by reduing the overall search space.
#
#
# **random_state** int, RandomState instance, default=None
#
# > This can impact the model when there are ties for best split, or when you're using random feature selection / max_features. For deterministic results, use it. If you don't need totally deterministic results, you can ignore it.
#
#
# **max_leaf_nodes** int, default=None
#
# > Grow a tree with max_leaf_nodes in best-first fashion. Best nodes are defined as relative reduction in impurity. If None then unlimited number of leaf nodes. An alternative way to perform regularization / stop the model from overfitting. Different from others above because it will cause the tree to grow "best split first" rather than just building the tree layer by layer.
#
#
# **min_impurity_decrease** float, default=0.0
#
# > A node will be split if this split induces a decrease of the impurity greater than or equal to this value. If splitting a node can't improve our metric (gini/entropy) by at least this much then a node won't be split. This will help us avoid overfitting, and it will smooth out our model somewhat, similar to min_samples_split.
#
#
# **class_weight** dict, list of dict or “balanced”, default=None
#
# > Weights associated with classes in the form {class_label: weight}. If None, all classes are supposed to have weight one. For multi-output problems, a list of dicts can be provided in the same order as the columns of y. See this link for more:
#
# **ccp_alpha** non-negative float, default=0.0
#
# > Complexity parameter used for Minimal Cost-Complexity Pruning. The subtree with the largest cost complexity that is smaller than ccp_alpha will be chosen. By default, no pruning is performed. See Minimal Cost-Complexity Pruning [(learn more here)](https://machinelearningmastery.com/cost-sensitive-decision-trees-for-imbalanced-classification/)

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV


# Load the data
heart_dataset = pd.read_csv('../datasets/uci-heart-disease/heart.csv')

# Split the data into input and labels
labels = heart_dataset['target']
input_data = heart_dataset.drop(columns=['target'])

# Note, we don't split the data. GridSearchCV will automatically apply 5-fold cross validation by default.


# Note, leaving out class_weights because our data is pretty balanced. 
tuned_parameters = {
    'criterion': ['gini', 'entropy'], # Not sure what will win out here TBH. Maybe gini.
    'splitter': ['best', 'random'], # best will be best, 
    'max_depth': [None, 5, 10], # None is probably best, allow the tree to grow as much as it needs
    'min_samples_split': [2, 10, 30], # 2 gives the model the most power to overfit, but I think it will win.
    'max_features':['auto', 'sqrt', 'log2'], # auto will probably be best.
    'max_leaf_nodes': [None, 4, 20], # I suspect 4 will be quite bad, and None will win
    'min_impurity_decrease': [0, 0.01, 0.5, 1, 5] # I added several b/c I'm curious. I think 0 will be best, relying on other params to smooth things.
}

# These two lines will result in every possible combo of the above paramters to be fit and scored
# which can take a LONG TIME with large datasets.
clf = DecisionTreeClassifier()
grid_tree = GridSearchCV(clf, tuned_parameters)
grid_tree.fit(input_data, labels) 

print("Best parameters set found on development set:")
print()
print(grid_tree.best_params_, grid_tree.best_score_)
print()
print("Grid scores on development set:")
print()
means = grid_tree.cv_results_['mean_test_score']
stds = grid_tree.cv_results_['std_test_score']



for mean, std, params in zip(means, stds, grid_tree.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'} 0.8248087431693989
#
# Grid scores on development set:
#
# 0.729 (+/-0.112) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.746 (+/-0.036) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.746 (+/-0.059) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.736 (+/-0.084) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.739 (+/-0.042) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.795 (+/-0.080) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.799 (+/-0.085) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.720 (+/-0.195) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.766 (+/-0.066) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.746 (+/-0.082) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.752 (+/-0.111) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.723 (+/-0.182) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.742 (+/-0.069) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.703 (+/-0.131) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.756 (+/-0.078) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.743 (+/-0.086) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.726 (+/-0.078) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.693 (+/-0.197) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.729 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.673 (+/-0.140) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.795 (+/-0.136) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.644 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.752 (+/-0.089) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.743 (+/-0.045) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.732 (+/-0.104) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.782 (+/-0.142) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.756 (+/-0.066) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.720 (+/-0.101) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.792 (+/-0.050) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.746 (+/-0.129) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.743 (+/-0.035) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.680 (+/-0.092) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.765 (+/-0.091) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.667 (+/-0.182) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.756 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.756 (+/-0.096) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.743 (+/-0.078) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.749 (+/-0.090) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.756 (+/-0.072) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.746 (+/-0.083) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.769 (+/-0.024) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.746 (+/-0.068) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.090) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.713 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.766 (+/-0.080) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.756 (+/-0.108) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.756 (+/-0.100) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.726 (+/-0.051) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.753 (+/-0.074) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.742 (+/-0.117) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.739 (+/-0.156) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.686 (+/-0.175) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.706 (+/-0.068) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.647 (+/-0.127) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.742 (+/-0.101) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.739 (+/-0.050) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.742 (+/-0.083) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.713 (+/-0.034) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.729 (+/-0.087) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.693 (+/-0.055) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.802 (+/-0.086) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.749 (+/-0.094) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.752 (+/-0.139) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.742 (+/-0.113) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.743 (+/-0.097) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.739 (+/-0.054) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.706 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.733 (+/-0.134) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.703 (+/-0.183) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.666 (+/-0.224) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.772 (+/-0.075) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.693 (+/-0.177) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.742 (+/-0.078) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.762 (+/-0.078) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.690 (+/-0.056) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.756 (+/-0.047) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.786 (+/-0.068) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.759 (+/-0.095) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.132) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.723 (+/-0.122) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.756 (+/-0.127) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.739 (+/-0.110) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.772 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.710 (+/-0.194) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.762 (+/-0.061) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.700 (+/-0.133) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.733 (+/-0.039) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.739 (+/-0.101) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.746 (+/-0.112) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.736 (+/-0.094) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.769 (+/-0.046) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.670 (+/-0.217) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.753 (+/-0.138) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.762 (+/-0.063) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.805 (+/-0.127) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.739 (+/-0.043) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.723 (+/-0.151) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.775 (+/-0.077) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.752 (+/-0.117) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.756 (+/-0.138) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.772 (+/-0.135) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.746 (+/-0.103) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.766 (+/-0.053) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.723 (+/-0.203) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.752 (+/-0.096) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.707 (+/-0.128) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.099) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.743 (+/-0.164) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# ...
# 0.743 (+/-0.127) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.772 (+/-0.097) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.756 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.663 (+/-0.135) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.772 (+/-0.074) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.746 (+/-0.222) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.759 (+/-0.172) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.733 (+/-0.111) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.799 (+/-0.092) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.716 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.769 (+/-0.104) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.696 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.756 (+/-0.104) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.716 (+/-0.012) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.726 (+/-0.161) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.677 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.723 (+/-0.024) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.683 (+/-0.153) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.749 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.772 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.749 (+/-0.081) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.752 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.749 (+/-0.148) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.766 (+/-0.139) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.756 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.789 (+/-0.043) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.799 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.671 (+/-0.218) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.756 (+/-0.076) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.743 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.729 (+/-0.150) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.674 (+/-0.137) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.5, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 2, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 5, 'min_samples_split': 30, 'splitter': 'random'}

# %%
results_df = pd.DataFrame({'mean_accuracy': means, 'std': stds})

params_df = pd.DataFrame(grid_tree.cv_results_['params'], columns=grid_tree.cv_results_['params'][0].keys())

sorted_performances = pd.concat([results_df, params_df], axis=1).sort_values('mean_accuracy', ascending=False)
sorted_performances = sorted_performances.sort_values('mean_accuracy', ascending=False)

sorted_performances.head(5)
# Out:
#       mean_accuracy       std criterion  max_depth max_features  \
# 368        0.824809  0.054669      gini        5.0         sqrt
# 966        0.808470  0.027581   entropy        NaN         sqrt
# 220        0.805137  0.063280      gini        NaN         log2
# 1084       0.805027  0.057348   entropy        5.0         auto
# 420        0.801803  0.043637      gini        5.0         sqrt
#
#       max_leaf_nodes  min_impurity_decrease  min_samples_split splitter
# 368              NaN                   0.01                 10     best
# 966             20.0                   0.01                  2     best
# 220              4.0                   0.01                 30     best
# 1084             NaN                   0.00                 30     best
# 420             20.0                   0.00                  2     best

# %%
sorted_performances.tail(5)
# Out:
#       mean_accuracy       std criterion  max_depth max_features  \
# 102         0.54459  0.004417      gini        NaN         sqrt
# 1363        0.54459  0.004417   entropy       10.0         auto
# 1456        0.54459  0.004417   entropy       10.0         sqrt
# 1364        0.54459  0.004417   entropy       10.0         auto
# 1619        0.54459  0.004417   entropy       10.0         log2
#
#       max_leaf_nodes  min_impurity_decrease  min_samples_split splitter
# 102              NaN                    0.5                  2     best
# 1363             NaN                    0.5                  2   random
# 1456             NaN                    0.5                 30     best
# 1364             NaN                    0.5                 10     best
# 1619            20.0                    5.0                 30   random

# %% [markdown]
# ## Any Patterns?
#
# What I see in the above is:
#
# `max_features` perform better when limited somehow vs unlimited (auto). Enforcing a `min_impurity_decrease` seems to hurt us, especially when using higher values.
#
# ## Bonus Challenges
#
# * Get the best performing model (look at the `best_estimator` property in the `GridSearchCV` documentation) and examine the `feature_importances_` of that `DecisionTree`. What are these, and what are they telling us?
#
# * Create another `GridSearchCV` but this time include more metrics to score the model.
#     * List of all built in metrics can be [found here](https://scikit-learn.org/stable/modules/classes.html#classification-metrics). I suggest using accuracy, precision, and recall.
#     * A demo of using multiple metrics can be [found here](https://scikit-learn.org/stable/auto_examples/model_selection/plot_multi_metric_evaluation.html#sphx-glr-auto-examples-model-selection-plot-multi-metric-evaluation-py)
#     * If you were building a real world medical screening system, how would you decide to value and balance these different metrics?
#         * [Read more about precision and recall](https://deepai.org/machine-learning-glossary-and-terms/precision-and-recall)
#         * Double bonus: can you make your GridSearch compute specificity as well? [Hint](https://stackoverflow.com/questions/47704133/how-to-define-specificity-as-a-callable-scorer-for-model-evaluation)

# %%
# Get the best estimator's feature importances.
# These tell us which features gave the model the most information as it split.
best_model = grid_tree.best_estimator_
feat_importances = pd.Series(best_model.feature_importances_, index=input_data.columns)
feat_importances.sort_values().plot(kind='barh', figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
# Multi Metric CV
from sklearn.metrics import accuracy_score, precision_score, recall_score, make_scorer

scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score),
    'recall': make_scorer(recall_score),
    'specificity': make_scorer(recall_score,pos_label=0) # Note, this is the double bonus. Not too bad!
}

tuned_parameters = {
    'criterion': ['gini', 'entropy'], # Not sure what will win out here TBH. Maybe gini.
    'splitter': ['best', 'random'], # best will be best, 
    'max_depth': [None, 5, 10], # None is probably best, allow the tree to grow as much as it needs
    'min_samples_split': [2, 10, 30], # 2 gives the model the most power to overfit, but I think it will win.
    'max_features':['auto', 'sqrt', 'log2'], # auto will probably be best.
    'max_leaf_nodes': [None, 4, 20], # I suspect 4 will be quite bad, and None will win
    'min_impurity_decrease': [0, 0.01, 0.5, 1, 5] # I added several b/c I'm curious. I think 0 will be best, relying on other params to smooth things.
}


clf = DecisionTreeClassifier()

# refit=false basically means we aren't choosing one estimator as the "best" one
# We do this because we have multi-metric scoring and it's no longer clear which is "best"
grid_tree = GridSearchCV(clf, tuned_parameters, scoring=scoring, refit=False) 
grid_tree.fit(input_data, labels) 

grid_tree.cv_results_
# Out:
# {'mean_fit_time': array([0.00265841, 0.00189533, 0.00170908, ..., 0.00166597, 0.0018929 ,
#         0.00172577]),
#  'std_fit_time': array([4.78287551e-04, 1.45436631e-04, 5.49279566e-05, ...,
#         8.28497667e-05, 3.64105766e-04, 1.23627296e-04]),
#  'mean_score_time': array([0.00413971, 0.00363469, 0.00325875, ..., 0.0033071 , 0.00421906,
#         0.00322022]),
#  'std_score_time': array([7.21266499e-04, 3.76124816e-04, 2.31055400e-04, ...,
#         2.51091916e-04, 6.39913317e-04, 8.77565126e-05]),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', ..., 'entropy', 'entropy',
#                     'entropy'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[None, None, None, ..., 10, 10, 10],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=['auto', 'auto', 'auto', ..., 'log2', 'log2', 'log2'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_leaf_nodes': masked_array(data=[None, None, None, ..., 20, 20, 20],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_impurity_decrease': masked_array(data=[0, 0, 0, ..., 5, 5, 5],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[2, 2, 10, ..., 10, 30, 30],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_splitter': masked_array(data=['best', 'random', 'best', ..., 'random', 'best',
#                     'random'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'auto',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
# ...
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 5,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   ...],
#  'split0_test_accuracy': array([0.70491803, 0.73770492, 0.78688525, ..., 0.54098361, 0.54098361,
#         0.54098361]),
#  'split1_test_accuracy': array([0.68852459, 0.72131148, 0.7704918 , ..., 0.54098361, 0.54098361,
#         0.54098361]),
#  'split2_test_accuracy': array([0.75409836, 0.68852459, 0.73770492, ..., 0.54098361, 0.54098361,
#         0.54098361]),
#  'split3_test_accuracy': array([0.73333333, 0.61666667, 0.76666667, ..., 0.55      , 0.55      ,
#         0.55      ]),
#  'split4_test_accuracy': array([0.63333333, 0.71666667, 0.61666667, ..., 0.55      , 0.55      ,
#         0.55      ]),
#  'mean_test_accuracy': array([0.70284153, 0.69617486, 0.73568306, ..., 0.54459016, 0.54459016,
#         0.54459016]),
#  'std_test_accuracy': array([0.04146731, 0.0427939 , 0.06158293, ..., 0.00441711, 0.00441711,
#         0.00441711]),
#  'rank_test_accuracy': array([564, 587, 368, ..., 649, 649, 649], dtype=int32),
#  'split0_test_precision': array([0.71428571, 0.74285714, 0.8125    , ..., 0.54098361, 0.54098361,
#         0.54098361]),
#  'split1_test_precision': array([0.73333333, 0.78571429, 0.82758621, ..., 0.54098361, 0.54098361,
#         0.54098361]),
#  'split2_test_precision': array([0.8       , 0.75      , 0.77419355, ..., 0.54098361, 0.54098361,
#         0.54098361]),
#  'split3_test_precision': array([0.81481481, 0.64705882, 0.80645161, ..., 0.55      , 0.55      ,
#         0.55      ]),
#  'split4_test_precision': array([0.65714286, 0.73529412, 0.65625   , ..., 0.55      , 0.55      ,
#         0.55      ]),
#  'mean_test_precision': array([0.74391534, 0.73218487, 0.77539627, ..., 0.54459016, 0.54459016,
#         0.54459016]),
#  'std_test_precision': array([0.05777817, 0.0459408 , 0.06206801, ..., 0.00441711, 0.00441711,
#         0.00441711]),
#  'rank_test_precision': array([434, 501, 182, ..., 649, 649, 649], dtype=int32),
#  'split0_test_recall': array([0.75757576, 0.78787879, 0.78787879, ..., 1.        , 1.        ,
#         1.        ]),
#  'split1_test_recall': array([0.66666667, 0.66666667, 0.72727273, ..., 1.        , 1.        ,
#         1.        ]),
#  'split2_test_recall': array([0.72727273, 0.63636364, 0.72727273, ..., 1.        , 1.        ,
#         1.        ]),
#  'split3_test_recall': array([0.66666667, 0.66666667, 0.75757576, ..., 1.        , 1.        ,
#         1.        ]),
#  'split4_test_recall': array([0.6969697 , 0.75757576, 0.63636364, ..., 1.        , 1.        ,
#         1.        ]),
#  'mean_test_recall': array([0.7030303 , 0.7030303 , 0.72727273, ..., 1.        , 1.        ,
#         1.        ]),
#  'std_test_recall': array([0.0353391 , 0.05875976, 0.05070667, ..., 0.        , 0.        ,
#         0.        ]),
#  'rank_test_recall': array([1587, 1587, 1536, ...,    1,    1,    1], dtype=int32),
#  'split0_test_specificity': array([0.64285714, 0.67857143, 0.78571429, ..., 0.        , 0.        ,
#         0.        ]),
#  'split1_test_specificity': array([0.71428571, 0.78571429, 0.82142857, ..., 0.        , 0.        ,
#         0.        ]),
#  'split2_test_specificity': array([0.78571429, 0.75      , 0.75      , ..., 0.        , 0.        ,
#         0.        ]),
#  'split3_test_specificity': array([0.81481481, 0.55555556, 0.77777778, ..., 0.        , 0.        ,
#         0.        ]),
#  'split4_test_specificity': array([0.55555556, 0.66666667, 0.59259259, ..., 0.        , 0.        ,
#         0.        ]),
#  'mean_test_specificity': array([0.7026455 , 0.68730159, 0.74550265, ..., 0.        , 0.        ,
#         0.        ]),
#  'std_test_specificity': array([0.09468682, 0.07934127, 0.0797811 , ..., 0.        , 0.        ,
#         0.        ]),
#  'rank_test_specificity': array([282, 358, 106, ..., 649, 649, 649], dtype=int32)}

# %%
# Plus, check out this trick making the DF a bit easier to work with
results = pd.DataFrame({
    'accuracy': grid_tree.cv_results_['mean_test_accuracy'],
    'precision': grid_tree.cv_results_['mean_test_precision'],
    'recall': grid_tree.cv_results_['mean_test_recall'],
    'specificity': grid_tree.cv_results_['mean_test_specificity'],
})

params_df = pd.DataFrame(grid_tree.cv_results_['params'], columns=grid_tree.cv_results_['params'][0].keys())
all_results = pd.concat([results, params_df], axis=1)

# Lots of interesting analysis could be done on this dataframe now to learn
# about the trained models...
all_results
# Out:
#       accuracy  precision    recall  specificity criterion  max_depth  \
# 0     0.702842   0.743915  0.703030     0.702646      gini        NaN
# 1     0.696175   0.732185  0.703030     0.687302      gini        NaN
# 2     0.735683   0.775396  0.727273     0.745503      gini        NaN
# 3     0.775628   0.802083  0.781818     0.767989      gini        NaN
# 4     0.712732   0.744234  0.733333     0.688624      gini        NaN
# ...        ...        ...       ...          ...       ...        ...
# 1615  0.544590   0.544590  1.000000     0.000000   entropy       10.0
# 1616  0.544590   0.544590  1.000000     0.000000   entropy       10.0
# 1617  0.544590   0.544590  1.000000     0.000000   entropy       10.0
# 1618  0.544590   0.544590  1.000000     0.000000   entropy       10.0
# 1619  0.544590   0.544590  1.000000     0.000000   entropy       10.0
#
#      max_features  max_leaf_nodes  min_impurity_decrease  min_samples_split  \
# 0            auto             NaN                    0.0                  2
# 1            auto             NaN                    0.0                  2
# 2            auto             NaN                    0.0                 10
# 3            auto             NaN                    0.0                 10
# 4            auto             NaN                    0.0                 30
# ...           ...             ...                    ...                ...
# 1615         log2            20.0                    5.0                  2
# 1616         log2            20.0                    5.0                 10
# 1617         log2            20.0                    5.0                 10
# 1618         log2            20.0                    5.0                 30
# 1619         log2            20.0                    5.0                 30
#
#      splitter
# 0        best
# 1      random
# 2        best
# 3      random
# 4        best
# ...       ...
# 1615   random
# 1616     best
# 1617   random
# 1618     best
# 1619   random
#
# [1620 rows x 11 columns]

# %% [markdown]
# # Part 2, Random Forests
#
# The only new hyperparamters are:
#
# **n_estimators**
#
# > the number of trees to build. More is "better" but you'll hit a point of diminishing returns as bagging and feature selection can only create so much variance.
#
# **bootstrap**
#
# > Whether or not to use bagging. Generally you want this, otherwise your only source of variance is feature selection.
#
# **oob_score**
#
# > When bagging, you can use "out of bag" samples as a form of validation data, rather than splitting out a validation set explicitly. If your number of estimators is fairly high, you may not have many out of bag samples. We're using a validation set anyway, so we won't use this.
#
# **n_jobs**
#
# > Speed impacting only, we can build these trees in parallel and this value controls how many processes to spin up in that parallel creation process.
#
# **warm_start**
#
# > Only relevant for retraining an existing random forest — warm start can be used to add new estimators when calling .fit more than once on the same model. We won't use this either.
#
# Also note splitter is no longer available, best is always used for RFs.

# %%
from sklearn.ensemble import RandomForestClassifier

# Load the data
heart_dataset = pd.read_csv('../datasets/uci-heart-disease/heart.csv')

# Split the data into input and labels
labels = heart_dataset['target']
input_data = heart_dataset.drop(columns=['target'])

# Note, we don't split the data. GridSearchCV will automatically apply 5-fold cross validation by default.


# Note, leaving out class_weights because our data is pretty balanced. 
tuned_parameters = {
    'n_estimators': [10, 50, 100, 200], # 10 is too few, I guess 200 not tons better than 100
    'bootstrap': [True, False], # I guess false will generally perform worse
    'n_jobs': [-1],  # always using max number of jobs
    'criterion': ['gini', 'entropy'], # Not sure what will win out here TBH. Maybe gini.
    'max_depth': [None, 5, 10], # None is probably best, allow the tree to grow as much as it needs
    'min_samples_split': [2, 10, 30], # 2 gives the model the most power to overfit, but I think it will win.
    'max_features':['sqrt', 'log2'], # auto will probably be best.
    'max_leaf_nodes': [None, 4, 20], # I suspect 4 will be quite bad, and None will win
}

# These two lines will result in every possible combo of the above paramters to be fit and scored
# which can take a LONG TIME with large datasets.
clf = RandomForestClassifier()
grid_tree = GridSearchCV(clf, tuned_parameters)
grid_tree.fit(input_data, labels) 

print("Best parameters set found on development set:")
print()
print(grid_tree.best_params_, grid_tree.best_score_)
print()
print("Grid scores on development set:")
print()
means = grid_tree.cv_results_['mean_test_score']
stds = grid_tree.cv_results_['std_test_score']

for mean, std, params in zip(means, stds, grid_tree.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
#
# {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1} 0.8546994535519126
#
# Grid scores on development set:
#
# 0.785 (+/-0.106) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.822 (+/-0.084) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.098) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.818 (+/-0.071) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.775 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.832 (+/-0.088) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.825 (+/-0.096) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.091) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.812 (+/-0.104) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.067) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.089) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.112) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.825 (+/-0.060) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.828 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.848 (+/-0.072) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.835 (+/-0.082) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.818 (+/-0.037) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.828 (+/-0.105) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.832 (+/-0.089) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.838 (+/-0.064) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.809 (+/-0.096) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.838 (+/-0.083) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.845 (+/-0.054) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.798 (+/-0.070) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.838 (+/-0.089) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.841 (+/-0.076) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.815 (+/-0.064) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.822 (+/-0.098) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.838 (+/-0.102) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.088) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.091) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.818 (+/-0.061) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.832 (+/-0.097) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.845 (+/-0.069) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.822 (+/-0.097) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.802 (+/-0.103) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.818 (+/-0.071) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.825 (+/-0.083) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.835 (+/-0.088) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.815 (+/-0.050) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.088) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.109) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.093) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.832 (+/-0.082) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.108) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.832 (+/-0.123) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.838 (+/-0.097) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.789 (+/-0.053) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.815 (+/-0.088) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.795 (+/-0.076) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.848 (+/-0.072) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.088) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.841 (+/-0.069) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.825 (+/-0.079) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.838 (+/-0.085) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.848 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.845 (+/-0.084) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.796 (+/-0.055) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.808 (+/-0.059) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.838 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.087) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.789 (+/-0.082) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.818 (+/-0.120) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.096) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.831 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.802 (+/-0.067) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.838 (+/-0.091) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.097) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.818 (+/-0.098) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.815 (+/-0.089) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.822 (+/-0.082) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.831 (+/-0.099) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.070) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.805 (+/-0.087) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.815 (+/-0.080) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.815 (+/-0.053) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.089) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.812 (+/-0.047) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.808 (+/-0.070) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.099) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.838 (+/-0.077) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.782 (+/-0.114) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.822 (+/-0.074) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.073) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.838 (+/-0.058) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.842 (+/-0.057) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.828 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.838 (+/-0.100) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.096) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.838 (+/-0.056) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.818 (+/-0.088) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.096) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.808 (+/-0.108) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.815 (+/-0.091) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.102) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.080) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.812 (+/-0.109) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.102) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.100) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.828 (+/-0.074) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.822 (+/-0.090) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.838 (+/-0.103) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.838 (+/-0.089) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.792 (+/-0.045) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.818 (+/-0.099) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.818 (+/-0.076) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.822 (+/-0.071) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.828 (+/-0.059) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.100) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.070) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.812 (+/-0.075) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.815 (+/-0.092) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.082) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.838 (+/-0.071) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.841 (+/-0.108) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.805 (+/-0.112) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.842 (+/-0.057) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.093) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.835 (+/-0.077) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.832 (+/-0.092) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.091) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.818 (+/-0.053) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.076) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.848 (+/-0.080) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.825 (+/-0.060) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.809 (+/-0.068) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.825 (+/-0.089) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.818 (+/-0.077) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.815 (+/-0.121) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.818 (+/-0.083) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.068) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.812 (+/-0.077) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.831 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.069) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.845 (+/-0.091) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.841 (+/-0.081) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.815 (+/-0.087) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.052) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.815 (+/-0.092) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.069) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.828 (+/-0.080) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.828 (+/-0.081) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.835 (+/-0.103) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.832 (+/-0.095) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.851 (+/-0.070) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.095) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.815 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.842 (+/-0.082) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.851 (+/-0.091) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.838 (+/-0.080) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.835 (+/-0.084) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.073) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.076) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.845 (+/-0.081) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.828 (+/-0.089) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.076) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.077) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.087) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.818 (+/-0.083) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.076) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.065) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.822 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.812 (+/-0.058) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.812 (+/-0.061) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.091) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.062) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.822 (+/-0.052) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.838 (+/-0.104) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.111) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.792 (+/-0.065) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.061) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.818 (+/-0.092) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.091) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.812 (+/-0.098) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.815 (+/-0.061) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.825 (+/-0.089) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.075) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.808 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.818 (+/-0.073) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.841 (+/-0.100) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.095) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.815 (+/-0.102) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.841 (+/-0.098) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.809 (+/-0.091) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.845 (+/-0.086) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.789 (+/-0.059) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.842 (+/-0.054) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.089) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.085) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.812 (+/-0.040) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.832 (+/-0.077) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.084) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.096) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.812 (+/-0.050) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.818 (+/-0.106) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.825 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.835 (+/-0.077) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.795 (+/-0.068) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.076) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.825 (+/-0.066) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.835 (+/-0.080) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.795 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.108) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.102) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.835 (+/-0.101) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.799 (+/-0.067) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.818 (+/-0.073) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.046) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.818 (+/-0.088) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.825 (+/-0.069) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.831 (+/-0.091) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.086) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.089) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.818 (+/-0.066) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.095) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.082) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.835 (+/-0.101) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.812 (+/-0.036) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.050) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.089) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.083) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.832 (+/-0.080) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.057) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.841 (+/-0.081) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.838 (+/-0.057) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.802 (+/-0.077) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.842 (+/-0.065) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.832 (+/-0.072) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.848 (+/-0.089) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.812 (+/-0.089) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.828 (+/-0.069) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.838 (+/-0.086) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.835 (+/-0.068) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.815 (+/-0.084) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.802 (+/-0.077) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.825 (+/-0.089) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.818 (+/-0.079) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.828 (+/-0.089) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.845 (+/-0.079) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.832 (+/-0.104) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.095) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.789 (+/-0.041) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.087) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.073) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.087) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.825 (+/-0.084) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# ...
# 0.805 (+/-0.055) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.077) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.812 (+/-0.076) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.835 (+/-0.077) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.825 (+/-0.051) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.812 (+/-0.082) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.815 (+/-0.078) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.812 (+/-0.075) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.832 (+/-0.102) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.832 (+/-0.075) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.845 (+/-0.078) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.086) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.795 (+/-0.090) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.812 (+/-0.071) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.802 (+/-0.077) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.815 (+/-0.093) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.812 (+/-0.047) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.822 (+/-0.072) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.083) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.063) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.822 (+/-0.068) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.828 (+/-0.114) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.085) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.081) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.828 (+/-0.095) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.845 (+/-0.094) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.825 (+/-0.069) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.079) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.818 (+/-0.089) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.842 (+/-0.080) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.832 (+/-0.066) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.822 (+/-0.079) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.828 (+/-0.080) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.835 (+/-0.065) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.088) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.818 (+/-0.073) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.808 (+/-0.093) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.812 (+/-0.067) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.077) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.818 (+/-0.060) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.815 (+/-0.044) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.822 (+/-0.128) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.818 (+/-0.074) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.083) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.825 (+/-0.077) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.831 (+/-0.086) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.831 (+/-0.093) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.838 (+/-0.075) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.772 (+/-0.047) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.815 (+/-0.075) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.818 (+/-0.080) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.812 (+/-0.108) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.822 (+/-0.097) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.825 (+/-0.084) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.822 (+/-0.069) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.828 (+/-0.066) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.822 (+/-0.112) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.828 (+/-0.073) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.076) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.066) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.832 (+/-0.050) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.841 (+/-0.096) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.825 (+/-0.087) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.825 (+/-0.082) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.808 (+/-0.096) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.818 (+/-0.053) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.825 (+/-0.069) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.818 (+/-0.082) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.818 (+/-0.069) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.841 (+/-0.082) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.835 (+/-0.095) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.835 (+/-0.077) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}
# 0.841 (+/-0.079) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1}
# 0.831 (+/-0.084) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 50, 'n_jobs': -1}
# 0.818 (+/-0.079) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': -1}
# 0.822 (+/-0.069) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 2, 'n_estimators': 200, 'n_jobs': -1}
# 0.808 (+/-0.102) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1}
# 0.822 (+/-0.069) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1}
# 0.815 (+/-0.086) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.075) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 10, 'n_estimators': 200, 'n_jobs': -1}
# 0.828 (+/-0.097) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 10, 'n_jobs': -1}
# 0.848 (+/-0.058) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 50, 'n_jobs': -1}
# 0.828 (+/-0.088) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 100, 'n_jobs': -1}
# 0.832 (+/-0.083) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_samples_split': 30, 'n_estimators': 200, 'n_jobs': -1}

# %%
results = pd.DataFrame({'mean_accuracy': means, 'std': stds})
params_df = pd.DataFrame(grid_tree.cv_results_['params'], columns=grid_tree.cv_results_['params'][0].keys())
all_results = pd.concat([results, params_df], axis=1)
sorted_performances = all_results.sort_values('mean_accuracy', ascending=False)

sorted_performances.head(5)
# Out:
#      mean_accuracy       std  bootstrap criterion  max_depth max_features  \
# 377       0.854699  0.032535       True   entropy       10.0         sqrt
# 154       0.851421  0.034981       True      gini       10.0         sqrt
# 484       0.851366  0.046237      False      gini        NaN         log2
# 270       0.851311  0.038451       True   entropy        NaN         log2
# 285       0.851311  0.047462       True   entropy        NaN         log2
#
#      max_leaf_nodes  min_samples_split  n_estimators  n_jobs
# 377             4.0                 10            50      -1
# 154             NaN                 30           100      -1
# 484             4.0                 10            10      -1
# 270             4.0                 10           100      -1
# 285            20.0                 30            50      -1

# %%
sorted_performances.tail(5)
# Out:
#      mean_accuracy       std  bootstrap criterion  max_depth max_features  \
# 84        0.781858  0.056760       True      gini        5.0         sqrt
# 4         0.775410  0.043213       True      gini        NaN         sqrt
# 828       0.772131  0.023348      False   entropy       10.0         log2
# 612       0.768798  0.038642      False      gini       10.0         log2
# 468       0.765574  0.045000      False      gini        NaN         log2
#
#      max_leaf_nodes  min_samples_split  n_estimators  n_jobs
# 84              4.0                  2            10      -1
# 4               NaN                 10            10      -1
# 828             NaN                  2            10      -1
# 612             NaN                  2            10      -1
# 468             NaN                  2            10      -1

# %% [markdown]
# ### Any Patterns?
#
# A surprise in the top 5, an `n_estimators = 10`, yet ALL the worst ones are the same. very interesting. It's the clear outlier though, the rest of the best are 100 or 200.
#
# Interesting that `max_leaf_nodes = 4` is 3/5 in the top 5, and None in 4/5 of the worst... Using "weak learners" in RF is common, and this is possibly an example of that. Having too many strong learners reduces the value of ensembling.
#
# ### Note, part 2 bonuses:
#
# The code changes are identical for part 2 and part 1, so refer to part 1 for the answers.
#
# ## Part 3: Comparing Results
#
# Write a few paragraphs summarizing the differences you've found with this dataset and these two types of model. While writing, consider the following:
#
# * Is one of these two model types better "on average"?
#     * **the best RFs are better than the best DTs**
# * Consider the best and worse performing models of each type:
#     * Are the worst performing models similarly bad, or is one much better?
#     * What about the best performing, are they similarly good or is one much better?
# * Compare the training times for each type.
#     * Was one much faster than the other?
#         * **RF is much more expensive to train**
#     * Which hyperparameters could a major impact on time to train?
#         * **n_estimators, n_jobs, n_features are all big ones for training times**
#     * Imagine your dataset became much larger, could the time-to-train become a serious problem?
#         * **absolutely**
#
# **Bonus challenge**
#
# * Compute and compare the 'feature importances' for each of your best performing models (the best performing DT and best performing RF).
#     * Did both models consider the same features to be "most important"?
#     * What about "least important"?
#
# **Looking below, the distributions are actually very different. Less domination by any one feature, and the order is totally different. This isn't too surprising since the whole construction of an RF forces "non-optimal" choices, so we'd expect a flatter distribution as well as a different order as a result.**

# %%
# Grabbing the RF importances...
best_model = grid_tree.best_estimator_
feat_importances = pd.Series(best_model.feature_importances_, index=input_data.columns)
feat_importances.sort_values().plot(kind='barh', figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
# Just for fun, I made a few charts related to the top 50 performing RFs and the relative commonality 
# of the hyperparameters.
from matplotlib import pyplot as plt
top_50 = sorted_performances.head(50)
top_50 = top_50.drop(columns=['mean_accuracy', 'std'])

for col in top_50.columns:
    top_50[col].value_counts(dropna=False).plot.pie()
    print(col)
    plt.show()
# Out:
# bootstrap
# criterion
# max_depth
# max_features
# max_leaf_nodes
# min_samples_split
# n_estimators
# n_jobs
